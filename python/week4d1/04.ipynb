# %%
import pandas as pd

# %%
data = pd.read_csv("stores.csv")
data.head(2)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
## Find out the top 5 most valuable transactions by Quantity
data.sort_values(by = "Quantity",ascending=False).head(5)
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 6488    6489  CA-2012-120621  3/21/2012   3/26/2012  Standard Class
# 8521    8522  CA-2013-141887  1/11/2013   1/15/2013  Standard Class
# 5668    5669  CA-2013-142405  6/12/2013   6/16/2013  Standard Class
# 9979    9980  US-2013-103674  12/7/2013  12/11/2013  Standard Class
# 8935    8936  CA-2014-130036  8/28/2014   8/28/2014        Same Day
#
#      Customer ID Customer Name      Segment        Country          City  ...  \
# 6488    JW-16075    Julia West     Consumer  United States  Jacksonville  ...
# 8521    MP-17470   Mark Packer  Home Office  United States      Columbus  ...
# 5668    SE-20110  Sanjit Engle     Consumer  United States       Seattle  ...
# 9979    AP-10720    Anne Pryor  Home Office  United States   Los Angeles  ...
# 8935    BP-11185  Ben Peterman    Corporate  United States  Philadelphia  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
## Sort all the transactions first by desc Quantity and then in asc order by Profit
data.sort_values(by = ['Quantity','Profit'],ascending=[False,True]).head(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 660      661  CA-2012-146563   8/24/2012   8/28/2012  Standard Class
# 1363    1364  US-2014-155425  11/11/2014  11/12/2014     First Class
# 8074    8075  CA-2014-151750    1/2/2014    1/6/2014  Standard Class
# 1045    1046  CA-2014-152702  10/13/2014  10/17/2014  Standard Class
# 9515    9516  CA-2011-154165   2/18/2011   2/25/2011  Standard Class
#
#      Customer ID      Customer Name      Segment        Country        City  \
# 660     CB-12025  Cassandra Brandow     Consumer  United States   Arlington
# 1363    AB-10600          Ann Blume    Corporate  United States      Tucson
# 8074    JM-15250       Janet Martin     Consumer  United States  Huntsville
# 1045    SN-20710       Steve Nguyen  Home Office  United States    Rockford
# 9515    DL-13315  Delfina Latchford     Consumer  United States     Chicago
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...
