# %%
import pandas as pd

# %%
data1 = pd.read_csv("sample1.csv")
data1
# Out:
#     Name  Age Gender
# 0  Sumit   12      M
# 1    Rob   21      M
# 2  Emily   45      F

# %%
data2 = pd.read_table("sample2.txt",sep="|")
data2
# Out:
#     Name  Age Gender
# 0  Sumit   12      M
# 1    Rob   21      M
# 2  Emily   45      F

# %%
data3 = pd.read_csv("tweets_assignment.txt",sep="|")
data3
# Out:
#                         Tweet_Date  \
# 0      Thu Dec 26 123415 0000 2013
# 1      Thu Dec 26 123413 0000 2013
# 2      Thu Dec 26 123402 0000 2013
# 3      Thu Dec 26 123354 0000 2013
# 4      Thu Dec 26 123351 0000 2013
# ...                            ...
# 14268  Mon Dec 23 043700 0000 2013
# 14269  Mon Dec 23 043649 0000 2013
# 14270  Mon Dec 23 043625 0000 2013
# 14271  Mon Dec 23 043610 0000 2013
# 14272  Mon Dec 23 043538 0000 2013
#
#                                               Tweet_Text     Tweet_Handle
# 0      ashdubey ratigirl FirstpostBiz First economic ...   maverickenator
# 1      RT anandpassion Growing popularity can seen as...          aapkask
# 2      RT anandpassion Growing popularity can seen as...       arpshalder
# 3      ArvindKejriwal AapYogendra AamAadmiParty I hop...           GargaC
# 4      RT ssttuuttii Press Conference AamAadmiParty A...  kejriwalfanclub
# ...                                                  ...              ...
# ...
