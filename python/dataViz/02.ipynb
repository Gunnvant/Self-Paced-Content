# %%
import pandas as pd
age_sal = pd.read_csv("age_sal.csv")

# %%
age_sal.head(2)
# Out:
#    Age  Annual Salary  Weekly hours                    Education
# 0   72       160000.0          40.0  Bachelor's degree or higher
# 1   72       100000.0          50.0  Bachelor's degree or higher

# %%
age_sal.plot(x="Age",y="Annual Salary",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Annual Salary'>

# %% [markdown]
# ## Using Seaborn

# %%
import seaborn as sns

# %%
sns.relplot(data=age_sal, x="Age", y="Annual Salary")

# %%
sns.relplot(data=age_sal, x="Age", y="Annual Salary",hue="Education")
